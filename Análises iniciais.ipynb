# %%
import pandas as pd

# %%
caminho = r'C:\EP04\2020\votacao_candidato_munzona_2020_BRASIL.csv'

# %%
df =pd.read_csv(caminho, delimiter=';', encoding='iso-8859-1', usecols=['NM_MUNICIPIO','SG_UF','SQ_CANDIDATO','DS_CARGO','DS_SITUACAO_CANDIDATURA','DS_DETALHE_SITUACAO_CAND','SG_PARTIDO','QT_VOTOS_NOMINAIS'])

# %%
df
# Out:
#        SG_UF        NM_MUNICIPIO  DS_CARGO  SQ_CANDIDATO  \
# 0         CE           FORTALEZA  Vereador   60000936791
# 1         AM              MANAUS  Vereador   40001182178
# 2         SP             CARDOSO  Vereador  250001266444
# 3         SC            CRICIÚMA  Vereador  240000980207
# 4         MG             UBERABA  Vereador  130000757747
# ...      ...                 ...       ...           ...
# 972163    SP           SÃO PAULO  Vereador  250000811391
# 972164    PR           MATO RICO  Vereador  160000732676
# 972165    SP  ARAÇOIABA DA SERRA  Vereador  250001035155
# 972166    RJ      RIO DE JANEIRO  Vereador  190001233804
# 972167    MG          UBERLÂNDIA  Vereador  130001011361
#
#        DS_SITUACAO_CANDIDATURA DS_DETALHE_SITUACAO_CAND    SG_PARTIDO  \
# 0                         APTO                 DEFERIDO          PSDB
# 1                         APTO                 DEFERIDO  REPUBLICANOS
# 2                         APTO                 DEFERIDO          PSDB
# 3                         APTO                 DEFERIDO      PATRIOTA
# 4                         APTO                 DEFERIDO  REPUBLICANOS
# ...                        ...                      ...           ...
# 972163                    APTO                 DEFERIDO          PODE
# 972164                    APTO                 DEFERIDO           PSD
# 972165                    APTO                 DEFERIDO           PSD
# 972166                    APTO                 DEFERIDO           PDT
# 972167                    APTO                 DEFERIDO           PSC
#
#         QT_VOTOS_NOMINAIS
# 0                      29
# 1                      78
# 2                      11
# 3                       2
# 4                      19
# ...                   ...
# 972163                 16
# 972164                 26
# 972165                170
# 972166                  8
# 972167                 22
#
# [972168 rows x 8 columns]

# %%
caminho = r'C:\EP04\2020\consulta_cand_2020_BRASIL.csv'

# %%
dfdescr =pd.read_csv(caminho, delimiter=';', encoding='iso-8859-1', usecols=['SQ_CANDIDATO','NR_IDADE_DATA_POSSE', 'DS_GENERO', 'DS_GRAU_INSTRUCAO','DS_COR_RACA','DS_OCUPACAO',])

# %%
dfdescr
# Out:
#         SQ_CANDIDATO  NR_IDADE_DATA_POSSE  DS_GENERO  \
# 0        80000952936                   67  MASCULINO
# 1       250001139050                   52   FEMININO
# 2        50001178649                   37   FEMININO
# 3       130001023806                   28  MASCULINO
# 4        90001021581                   30  MASCULINO
# ...              ...                  ...        ...
# 557628  250001264623                   60  MASCULINO
# 557629  190001072004                   62  MASCULINO
# 557630   50001255977                   60  MASCULINO
# 557631  250001178910                   56  MASCULINO
# 557632  170000920449                   47   FEMININO
#
#                     DS_GRAU_INSTRUCAO     DS_COR_RACA  \
# 0                   SUPERIOR COMPLETO           PARDA
# 1       ENSINO FUNDAMENTAL INCOMPLETO           PARDA
# 2         ENSINO FUNDAMENTAL COMPLETO  SEM INFORMAÇÃO
# 3               ENSINO MÉDIO COMPLETO           PARDA
# 4               ENSINO MÉDIO COMPLETO          BRANCA
# ...                               ...             ...
# 557628  ENSINO FUNDAMENTAL INCOMPLETO          BRANCA
# 557629          ENSINO MÉDIO COMPLETO          BRANCA
# 557630          ENSINO MÉDIO COMPLETO           PARDA
# 557631  ENSINO FUNDAMENTAL INCOMPLETO           PRETA
# 557632          ENSINO MÉDIO COMPLETO          BRANCA
#
#                                         DS_OCUPACAO
# 0              APOSENTADO (EXCETO SERVIDOR PÚBLICO)
# 1                                      DONA DE CASA
# 2                                            OUTROS
# 3                                          VEREADOR
# 4                                            OUTROS
# ...                                             ...
# 557628         APOSENTADO (EXCETO SERVIDOR PÚBLICO)
# 557629                   SERVIDOR PÚBLICO MUNICIPAL
# 557630                                       OUTROS
# 557631  VENDEDOR DE COMÉRCIO VAREJISTA E ATACADISTA
# 557632                                       OUTROS
#
# [557633 rows x 6 columns]

# %%
caminho = r'C:\EP04\IBGE_c.csv'

# %%
dflocal =pd.read_csv(caminho, delimiter=',', encoding='iso-8859-1', usecols=['nome','latitude','longitude'])

# %%
dflocal['NM_MUNICIPIO'] = dflocal['nome'].str.upper()

# %%
dflocal = dflocal.drop(columns=['nome'])

# %%
dflocal
# Out:
#       latitude  longitude         NM_MUNICIPIO
# 0    -16.75730   -49.4412      ABADIA DE GOIÁS
# 1    -18.48310   -47.3916  ABADIA DOS DOURADOS
# 2    -16.19700   -48.7057            ABADIÂNIA
# 3    -19.15510   -45.4444               ABAETÉ
# 4     -1.72183   -48.8788           ABAETETUBA
# ...        ...        ...                  ...
# 5565 -10.82300   -42.7245          XIQUE-XIQUE
# 5566  -8.07901   -37.1057              ZABELÃª
# 5567 -21.05060   -50.0552             ZACARIAS
# 5568  -3.27014   -45.6553              ZÉ DOCA
# 5569 -27.45210   -51.5520               ZORTÉA
#
# [5570 rows x 3 columns]

# %%
df1 = pd.merge(df,dfdescr, on = "SQ_CANDIDATO")

# %%
df1
# Out:
#        SG_UF         NM_MUNICIPIO  DS_CARGO  SQ_CANDIDATO  \
# 0         CE            FORTALEZA  Vereador   60000936791
# 1         CE            FORTALEZA  Vereador   60000936791
# 2         CE            FORTALEZA  Vereador   60000936791
# 3         CE            FORTALEZA  Vereador   60000936791
# 4         CE            FORTALEZA  Vereador   60000936791
# ...      ...                  ...       ...           ...
# 972838    SP  PATROCÍNIO PAULISTA  Vereador  250001120544
# 972839    BA  TEIXEIRA DE FREITAS  Vereador   50000787574
# 972840    MG   SÃO BRÁS DO SUAÇUÍ  Vereador  130000773784
# 972841    PR            MATO RICO  Vereador  160000732676
# 972842    SP   ARAÇOIABA DA SERRA  Vereador  250001035155
#
#        DS_SITUACAO_CANDIDATURA DS_DETALHE_SITUACAO_CAND SG_PARTIDO  \
# 0                         APTO                 DEFERIDO       PSDB
# 1                         APTO                 DEFERIDO       PSDB
# 2                         APTO                 DEFERIDO       PSDB
# 3                         APTO                 DEFERIDO       PSDB
# 4                         APTO                 DEFERIDO       PSDB
# ...                        ...                      ...        ...
# 972838                    APTO                 DEFERIDO  CIDADANIA
# 972839                    APTO                 DEFERIDO        PSB
# 972840                    APTO                 DEFERIDO         PP
# 972841                    APTO                 DEFERIDO        PSD
# 972842                    APTO                 DEFERIDO        PSD
#
#         QT_VOTOS_NOMINAIS  NR_IDADE_DATA_POSSE  DS_GENERO  \
# 0                      29                   58   FEMININO
# 1                      11                   58   FEMININO
# 2                       3                   58   FEMININO
# 3                      35                   58   FEMININO
# 4                       5                   58   FEMININO
# ...                   ...                  ...        ...
# 972838                126                   34   FEMININO
# 972839                 30                   34  MASCULINO
# 972840                 16                   49  MASCULINO
# 972841                 26                   48   FEMININO
# 972842                170                   61  MASCULINO
#
#                     DS_GRAU_INSTRUCAO DS_COR_RACA  \
# 0               ENSINO MÉDIO COMPLETO      BRANCA
# 1               ENSINO MÉDIO COMPLETO      BRANCA
# 2               ENSINO MÉDIO COMPLETO      BRANCA
# 3               ENSINO MÉDIO COMPLETO      BRANCA
# 4               ENSINO MÉDIO COMPLETO      BRANCA
# ...                               ...         ...
# 972838              SUPERIOR COMPLETO       PARDA
# 972839          ENSINO MÉDIO COMPLETO      BRANCA
# 972840  ENSINO FUNDAMENTAL INCOMPLETO       PARDA
# 972841          ENSINO MÉDIO COMPLETO       PARDA
# 972842  ENSINO FUNDAMENTAL INCOMPLETO      BRANCA
#
#                                            DS_OCUPACAO
# 0                                           EMPRESÁRIO
# 1                                           EMPRESÁRIO
# 2                                           EMPRESÁRIO
# 3                                           EMPRESÁRIO
# 4                                           EMPRESÁRIO
# ...                                                ...
# 972838  PROFESSOR E INSTRUTOR DE FORMAÇÃO PROFISSIONAL
# 972839                                          OUTROS
# 972840                                          OUTROS
# 972841                      SERVIDOR PÚBLICO MUNICIPAL
# 972842                                          OUTROS
#
# [972843 rows x 13 columns]

# %%
dfTotal = pd.merge(df1,dflocal, on ='NM_MUNICIPIO')

# %%
dfTotal.head(5)
# Out:
#   SG_UF NM_MUNICIPIO  DS_CARGO  SQ_CANDIDATO DS_SITUACAO_CANDIDATURA  \
# 0    CE    FORTALEZA  Vereador   60000936791                    APTO
# 1    CE    FORTALEZA  Vereador   60000936791                    APTO
# 2    CE    FORTALEZA  Vereador   60000936791                    APTO
# 3    CE    FORTALEZA  Vereador   60000936791                    APTO
# 4    CE    FORTALEZA  Vereador   60000936791                    APTO
#
#   DS_DETALHE_SITUACAO_CAND SG_PARTIDO  QT_VOTOS_NOMINAIS  NR_IDADE_DATA_POSSE  \
# 0                 DEFERIDO       PSDB                 29                   58
# 1                 DEFERIDO       PSDB                 11                   58
# 2                 DEFERIDO       PSDB                  3                   58
# 3                 DEFERIDO       PSDB                 35                   58
# 4                 DEFERIDO       PSDB                  5                   58
#
#   DS_GENERO      DS_GRAU_INSTRUCAO DS_COR_RACA DS_OCUPACAO  latitude  \
# 0  FEMININO  ENSINO MÉDIO COMPLETO      BRANCA  EMPRESÁRIO  -3.71664
# 1  FEMININO  ENSINO MÉDIO COMPLETO      BRANCA  EMPRESÁRIO  -3.71664
# 2  FEMININO  ENSINO MÉDIO COMPLETO      BRANCA  EMPRESÁRIO  -3.71664
# 3  FEMININO  ENSINO MÉDIO COMPLETO      BRANCA  EMPRESÁRIO  -3.71664
# 4  FEMININO  ENSINO MÉDIO COMPLETO      BRANCA  EMPRESÁRIO  -3.71664
#
#    longitude
# 0   -38.5423
# 1   -38.5423
# 2   -38.5423
# 3   -38.5423
# 4   -38.5423

# %%
Serie = dfTotal.groupby(['NM_MUNICIPIO','SG_UF','SQ_CANDIDATO','DS_CARGO','DS_SITUACAO_CANDIDATURA','DS_DETALHE_SITUACAO_CAND','SG_PARTIDO','DS_GENERO','DS_GRAU_INSTRUCAO','DS_OCUPACAO', 'DS_COR_RACA' ])['QT_VOTOS_NOMINAIS'].sum()

# %%
# Out:
# NM_MUNICIPIO     SG_UF  SQ_CANDIDATO  DS_CARGO  DS_SITUACAO_CANDIDATURA  DS_DETALHE_SITUACAO_CAND  SG_PARTIDO    DS_GENERO  DS_GRAU_INSTRUCAO              DS_OCUPACAO                                      DS_COR_RACA
# ABADIA DE GOIÁS  GO     90000780341   Vereador  APTO                     DEFERIDO                  REPUBLICANOS  FEMININO   ENSINO MÉDIO COMPLETO          CORRETOR DE IMÓVEIS, SEGUROS, TÍTULOS E VALORES  PRETA           18
#                         90000780342   Vereador  APTO                     DEFERIDO                  REPUBLICANOS  FEMININO   ENSINO FUNDAMENTAL INCOMPLETO  DONA DE CASA                                     PARDA            3
#                         90000780343   Vereador  APTO                     DEFERIDO                  REPUBLICANOS  MASCULINO  ENSINO MÉDIO COMPLETO          CORRETOR DE IMÓVEIS, SEGUROS, TÍTULOS E VALORES  PARDA           93
#                         90000780344   Vereador  APTO                     DEFERIDO                  REPUBLICANOS  MASCULINO  ENSINO MÉDIO INCOMPLETO        EMPRESÁRIO                                       PARDA          278
#                         90000780345   Vereador  APTO                     DEFERIDO                  REPUBLICANOS  MASCULINO  SUPERIOR COMPLETO              PROFESSOR DE ENSINO MÉDIO                        PARDA           99
#                                                                                                                                                                                                                           ...
# ÁUREA            RS     210001250106  Vereador  APTO                     DEFERIDO                  PTB           MASCULINO  ENSINO FUNDAMENTAL INCOMPLETO  APOSENTADO (EXCETO SERVIDOR PÚBLICO)             BRANCA          58
#                         210001250107  Vereador  APTO                     DEFERIDO                  PTB           MASCULINO  ENSINO FUNDAMENTAL INCOMPLETO  EMPRESÁRIO                                       BRANCA          47
#                         210001250108  Vereador  APTO                     DEFERIDO                  PTB           FEMININO   ENSINO MÉDIO COMPLETO          SERVIDOR PÚBLICO MUNICIPAL                       BRANCA          25
#                         210001250109  Vereador  APTO                     DEFERIDO                  PTB           MASCULINO  ENSINO FUNDAMENTAL INCOMPLETO  EMPRESÁRIO                                       BRANCA         106
#                         210001250110  Vereador  APTO                     DEFERIDO                  PTB           MASCULINO  ENSINO FUNDAMENTAL INCOMPLETO  APOSENTADO (EXCETO SERVIDOR PÚBLICO)             BRANCA          64
# Name: QT_VOTOS_NOMINAIS, Length: 494569, dtype: int64

# %%
dfx= Serie.to_frame()

# %%
dfx.query('SQ_CANDIDATO == "250001266824"')
# Out:
#                                                                                                                                                             QT_VOTOS_NOMINAIS
# NM_MUNICIPIO SG_UF SQ_CANDIDATO DS_CARGO DS_SITUACAO_CANDIDATURA DS_DETALHE_SITUACAO_CAND SG_PARTIDO   DS_GENERO DS_GRAU_INSTRUCAO DS_OCUPACAO DS_COR_RACA
# SÃO PAULO    SP    250001266824 Vereador APTO                    DEFERIDO                 REPUBLICANOS MASCULINO SUPERIOR COMPLETO ADVOGADO    BRANCA                     231

# %%
dfCandidatosZeroVoto = dfx.query('QT_VOTOS_NOMINAIS == 0 & DS_SITUACAO_CANDIDATURA=="APTO" & DS_DETALHE_SITUACAO_CAND== "DEFERIDO" & DS_CARGO=="Vereador"')

# %%
dfCandidatosZeroVoto
# Out:
#                                                                                                                                                                                                                     QT_VOTOS_NOMINAIS
# NM_MUNICIPIO          SG_UF SQ_CANDIDATO DS_CARGO DS_SITUACAO_CANDIDATURA DS_DETALHE_SITUACAO_CAND SG_PARTIDO   DS_GENERO DS_GRAU_INSTRUCAO             DS_OCUPACAO                                    DS_COR_RACA
# ABADIA DE GOIÁS       GO    90000818193  Vereador APTO                    DEFERIDO                 PSB          FEMININO  SUPERIOR INCOMPLETO           OUTROS                                         PARDA                        0
#                             90001028251  Vereador APTO                    DEFERIDO                 PL           MASCULINO LÊ E ESCREVE                  OUTROS                                         PARDA                        0
# ABADIÂNIA             GO    90001273386  Vereador APTO                    DEFERIDO                 MDB          FEMININO  SUPERIOR COMPLETO             FARMACÊUTICO                                   BRANCA                       0
# ABAETETUBA            PA    140000854784 Vereador APTO                    DEFERIDO                 PSC          FEMININO  ENSINO FUNDAMENTAL INCOMPLETO OUTROS                                         PRETA                        0
#                             140000933508 Vereador APTO                    DEFERIDO                 AVANTE       FEMININO  ENSINO MÉDIO COMPLETO         ESTUDANTE, BOLSISTA, ESTAGIÁRIO E ASSEMELHADOS PARDA                        0
# ...                                                                                                                                                                                                                               ...
# ÁGUAS LINDAS DE GOIÁS GO    90001024963  Vereador APTO                    DEFERIDO                 PTC          FEMININO  ENSINO FUNDAMENTAL INCOMPLETO DONA DE CASA                                   PARDA                        0
#                             90001143208  Vereador APTO                    DEFERIDO                 AVANTE       FEMININO  LÊ E ESCREVE                  OUTROS                                         PARDA                        0
# ÁGUAS VERMELHAS       MG    130001074825 Vereador APTO                    DEFERIDO                 REPUBLICANOS FEMININO  ENSINO MÉDIO COMPLETO         ESTUDANTE, BOLSISTA, ESTAGIÁRIO E ASSEMELHADOS PARDA                        0
#                             130001140018 Vereador APTO                    DEFERIDO                 PTC          FEMININO  ENSINO MÉDIO COMPLETO         OUTROS                                         PARDA                        0
# ÁLVARES MACHADO       SP    250001169795 Vereador APTO                    DEFERIDO                 PT           FEMININO  ENSINO MÉDIO COMPLETO         APOSENTADO (EXCETO SERVIDOR PÚBLICO)           BRANCA                       0
#
# [4442 rows x 1 columns]

# %%
Feminino = dfCandidatosZeroVoto.query('DS_GENERO=="FEMININO"').count()
Feminino
# Out:
# QT_VOTOS_NOMINAIS    3004
# dtype: int64

# %%
Masculino = dfCandidatosZeroVoto.query('DS_GENERO=="MASCULINO"').count()
Masculino
# Out:
# QT_VOTOS_NOMINAIS    1438
# dtype: int64
